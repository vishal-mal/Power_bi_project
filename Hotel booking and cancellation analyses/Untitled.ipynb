# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.read_csv('hotel_bookings.csv')

# %%
df1.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df1['babies'].unique()
# Out:
# array([ 0,  1,  2, 10,  9], dtype=int64)

# %%
df2 = df1[df1['babies']<=2]

# %%
df2['adults'].unique()
# Out:
# array([ 2,  1,  3,  4, 40, 26, 50, 27, 55,  0, 20,  6,  5, 10],
#       dtype=int64)

# %%
df2.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df2[df2['adults']==0].groupby('hotel').count()
# Out:
#               is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# hotel
# City Hotel            390        390                390                 390
# Resort Hotel           13         13                 13                  13
#
#               arrival_date_week_number  arrival_date_day_of_month  \
# hotel
# City Hotel                         390                        390
# Resort Hotel                        13                         13
#
#               stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# hotel
# City Hotel                        390                   390     390       390
# Resort Hotel                       13                    13      13        13
#
#               ...  deposit_type  agent  company  days_in_waiting_list  \
# hotel         ...
# City Hotel    ...           390    322       25                   390
# Resort Hotel  ...            13      4        6                    13
#
# ...

# %%
df2[(df2['adults'] == 0) | (df2['adults'] >= 20)]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 1539    Resort Hotel            1        304               2015
# 1587    Resort Hotel            1        333               2015
# 1643    Resort Hotel            1        336               2015
# 1752    Resort Hotel            1        340               2015
# 1884    Resort Hotel            1        347               2015
# ...              ...          ...        ...                ...
# 117204    City Hotel            0        296               2017
# 117274    City Hotel            0        276               2017
# 117303    City Hotel            0        291               2017
# 117453    City Hotel            0        159               2017
# 118200    City Hotel            0         10               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 1539            September                        36
# 1587            September                        36
# ...

# %%
len(df2)
# Out:
# 119388

# %%
df3 = df2.drop(df2[df2['adults'] == 0].index)

# %%
df3
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df4 = df3.drop(df3[df3['adults'] >= 20].index)

# %%
df4.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
len(df3)
# Out:
# 118985

# %%
len(df4)
# Out:
# 118973

# %%
df4.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df4['is_canceled'].value_counts()
# Out:
# is_canceled
# 0    74870
# 1    44103
# Name: count, dtype: int64

# %%
df4['hotel'].value_counts()
# Out:
# hotel
# City Hotel      78938
# Resort Hotel    40035
# Name: count, dtype: int64

# %%
df4['adults'].groupby(df4['hotel']).value_counts()
# Out:
# hotel         adults
# City Hotel    2         58254
#               1         15878
#               3          4775
#               4            31
# Resort Hotel  2         31425
#               1          7148
#               3          1427
#               4            31
#               5             2
#               6             1
#               10            1
# Name: count, dtype: int64

# %%
df4['babies'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df4['babies'].value_counts()
# Out:
# babies
# 0    118061
# 1       897
# 2        15
# Name: count, dtype: int64

# %%
df4['children'].value_counts()
# Out:
# children
# 0.0     110602
# 1.0       4857
# 2.0       3444
# 3.0         65
# 10.0         1
# Name: count, dtype: int64

# %%
df5 = df4.replace(0.0,0)

# %%
df6 = df5.replace(1.0,1)

# %%
df7 = df6.replace(3.0,3)

# %%
df7['children'].value_counts()
# Out:
# children
# 0.0     110602
# 1.0       4857
# 2.0       3444
# 3.0         65
# 10.0         1
# Name: count, dtype: int64

# %%
df8 = df7.drop(df7[df7['children'] == 10 ].index)

# %%
df8['children'].value_counts()
# Out:
# children
# 0.0    110602
# 1.0      4857
# 2.0      3444
# 3.0        65
# Name: count, dtype: int64

# %%
df8.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df8['children'].value_counts()
# Out:
# children
# 0.0    110602
# 1.0      4857
# 2.0      3444
# 3.0        65
# Name: count, dtype: int64

# %%
len(df8)
# Out:
# 118972

# %%
df8.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              478
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df9 = df8.drop(['arrival_date_week_number','arrival_date_day_of_month' ,'stays_in_weekend_nights' ,'stays_in_week_nights' ,'meal' ,'distribution_channel'
                ,'is_repeated_guest' ,'previous_cancellations' ,'previous_bookings_not_canceled' ,'booking_changes' ,'deposit_type' ,'agent' ,'company' 
                ,'days_in_waiting_list' ,'customer_type' ,'adr' ,'required_car_parking_spaces' ,'total_of_special_requests'],axis='columns')

# %%
df9['arrival_date_month'].unique()
# Out:
# array(['July', 'August', 'September', 'October', 'November', 'December',
#        'January', 'February', 'March', 'April', 'May', 'June'],
#       dtype=object)

# %%
df9.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    adults  children  babies country market_segment reserved_room_type  \
# 0       2       0.0       0     PRT         Direct                  C
# 1       2       0.0       0     PRT         Direct                  C
# 2       1       0.0       0     GBR         Direct                  A
# 3       1       0.0       0     GBR      Corporate                  A
# 4       2       0.0       0     GBR      Online TA                  A
#
#   assigned_room_type reservation_status reservation_status_date
# ...

# %%
df9.dtypes
# Out:
# hotel                       object
# is_canceled                  int64
# lead_time                    int64
# arrival_date_year            int64
# arrival_date_month          object
# adults                       int64
# children                   float64
# babies                       int64
# country                     object
# market_segment              object
# reserved_room_type          object
# assigned_room_type          object
# reservation_status          object
# reservation_status_date     object
# dtype: object

# %%
df9.isnull().sum()
# Out:
# hotel                        0
# is_canceled                  0
# lead_time                    0
# arrival_date_year            0
# arrival_date_month           0
# adults                       0
# children                     4
# babies                       0
# country                    478
# market_segment               0
# reserved_room_type           0
# assigned_room_type           0
# reservation_status           0
# reservation_status_date      0
# dtype: int64

# %%
df9['country'].value_counts()
# Out:
# country
# PRT    48426
# GBR    12104
# FRA    10376
# ESP     8546
# DEU     7271
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 177, dtype: int64

# %%
df9['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
df10 = df9.dropna()

# %%
df10.isnull().sum()
# Out:
# hotel                      0
# is_canceled                0
# lead_time                  0
# arrival_date_year          0
# arrival_date_month         0
# adults                     0
# children                   0
# babies                     0
# country                    0
# market_segment             0
# reserved_room_type         0
# assigned_room_type         0
# reservation_status         0
# reservation_status_date    0
# dtype: int64

# %%
len(df10)
# Out:
# 118490

# %%
df10['reserved_room_type'].unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'H', 'L', 'B'], dtype=object)

# %%
df10['assigned_room_type'].unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'I', 'B', 'H', 'L', 'K'],
#       dtype=object)

# %%
df10['lead_time']
# Out:
# 0         342
# 1         737
# 2           7
# 3          13
# 4          14
#          ...
# 119385     23
# 119386    102
# 119387     34
# 119388    109
# 119389    205
# Name: lead_time, Length: 118490, dtype: int64

# %%
df11 = df10.drop('market_segment',axis ='columns')

# %%
df11
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  adults  children  babies country  \
# 0                    July       2       0.0       0     PRT
# 1                    July       2       0.0       0     PRT
# ...

# %%
df12 = df11.drop('lead_time',axis ='columns')

# %%
df12
# Out:
#                hotel  is_canceled  arrival_date_year arrival_date_month  \
# 0       Resort Hotel            0               2015               July
# 1       Resort Hotel            0               2015               July
# 2       Resort Hotel            0               2015               July
# 3       Resort Hotel            0               2015               July
# 4       Resort Hotel            0               2015               July
# ...              ...          ...                ...                ...
# 119385    City Hotel            0               2017             August
# 119386    City Hotel            0               2017             August
# 119387    City Hotel            0               2017             August
# 119388    City Hotel            0               2017             August
# 119389    City Hotel            0               2017             August
#
#         adults  children  babies country reserved_room_type  \
# ...

# %%
df12.to_csv('training_data.csv', index=False)
